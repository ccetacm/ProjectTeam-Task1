# %%
import numpy as np 
import pandas as pd
from sklearn import feature_extraction, linear_model, model_selection, preprocessing

# %%
train_df = pd.read_csv("ProjectTeam-Task1/train.csv")
test_df = pd.read_csv("ProjectTeam-Task1/test.csv")

# %%
train_df.head

# %%
test_df.head

# %%
train_df[train_df["target"] == 0]["text"].values[1]

# %%
train_df[train_df["target"] == 1]["text"].values[1]

# %%
train_df['text'] = train_df['text'].apply(lambda s : clean(s))

# %%
count_vectorizer = feature_extraction.text.CountVectorizer()

# %%
train_vectors = count_vectorizer.fit_transform(train_df["text"])
test_vectors = count_vectorizer.transform(test_df["text"])

# %%
clf = linear_model.RidgeClassifier()

# %%
scores = model_selection.cross_val_score(clf, train_vectors, train_df["target"], cv=3, scoring="f1")
scores

# %%
clf.fit(train_vectors, train_df["target"])

# %%
sample_submission = pd.read_csv("ProjectTeam-Task1/sample_submission.csv")

# %%
sample_submission["target"] = clf.predict(test_vectors)

# %%
sample_submission.to_csv("RC-submission1.csv", index=False)
